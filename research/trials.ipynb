# %%
from box import ConfigBox

# %%
a = ConfigBox({"age":34, "salary":12000})

# %%
a.age
# Out:
# 34

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def calculate_sqaure(n1,n2) -> int:
    return n1*n2

# %%
# calculate_sqaure(3,"4")
