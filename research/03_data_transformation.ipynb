# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\siva\\end-to-end-ml-project-with-mlflow\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\siva\\end-to-end-ml-project-with-mlflow'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self, config_filepath = CONFIG_FILE_PATH, params_filepath = PARAMS_FILE_PATH, schema_filepath = SCHEMA_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)
        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self)-> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path
        )
        
        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
    
    #train test split (we can do all the feature engineering, eda, transformation, scaling stuff here!)

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)

        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index=False)

        logger.info("Splitted data into training and test data")
        logger.info(train.shape)
        logger.info(test.shape)

# %%
try:
    config =   ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config = data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2025-11-09 21:19:35,050: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-11-09 21:19:35,052: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-11-09 21:19:35,055: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-11-09 21:19:35,057: INFO: common: created directory at: artifacts]
# [2025-11-09 21:19:35,058: INFO: common: created directory at: artifacts/data_transformation]
# [2025-11-09 21:19:36,056: INFO: 1807327593: Splitted data into training and test data]
# [2025-11-09 21:19:36,057: INFO: 1807327593: (1199, 12)]
# [2025-11-09 21:19:36,057: INFO: 1807327593: (400, 12)]
